# %%
import pandas as pd
import random
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# columns = ['id','amount_currency','amount_value','channel','deviceDetails_browser',
#            'deviceDetails_device','deviceDetails_deviceIp','merchantRefTransactionId','paymentMethod_apmType',
#            'paymentMethod_cardNumber','paymentMethod_cardSubType','paymentMethod_cardType','paymentMethod_cvv',
#            'paymentMethod_encodedPaymentToken','paymentMethod_expiryMonth','paymentMethod_expiryYear',
#            'shopperDetails_address_addressLine1','shopperDetails_address_addressLine2',
#            'shopperDetails_address_city','shopperDetails_address_country','shopperDetails_address_postalCode',
#            'shopperDetails_address_state','shopperDetails_email','shopperDetails_firstName','shopperDetails_lastName',
#            'shopperDetails_phoneNumber','shopperDetails_shopperKey']

columns = ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.mounts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [MountInfo(mountPoint=&#39;/mnt/test-mount-1&#39;, source=&#39;abfss://container2@dapetroadlsgen2.dfs.core.windows.net/&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/training&#39;, source=&#39;wasbs://training@dbtraineastus.blob.core.windows.net/&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/databricks-cli-test1&#39;, source=&#39;abfss://container1@dapetroadlsgen2.dfs.core.windows.net/&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks-datasets&#39;, source=&#39;databricks-datasets&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks/mlflow-tracking&#39;, source=&#39;databricks/mlflow-tracking&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks-results&#39;, source=&#39;databricks-results&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/databricks-cli-test&#39;, source=&#39;abfss://container1@dapetroadlsgen2.dfs.core.windows.net/&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks/mlflow-registry&#39;, source=&#39;databricks/mlflow-registry&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/mount2&#39;, source=&#39;abfss://container2@dapetroadlsgen2.dfs.core.windows.net/&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/dsip&#39;, source=&#39;wasbs://data@dapetrodsipstorage.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/ta01entdls01/raw/&#39;, source=&#39;adl://dapetrodatalakegen1.azuredatalakestore.net/raw/&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/test-mount&#39;, source=&#39;abfss://container2@dapetroadlsgen2.dfs.core.windows.net/&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/ta01entdls01/transformed/&#39;, source=&#39;adl://dapetrodatalakegen1.azuredatalakestore.net/transformed/&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/&#39;, source=&#39;DatabricksRoot&#39;, encryptionType=&#39;&#39;)]</div>

# %%
# %fs ls "/mnt/dsip"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/dsip/data.csv</td><td>data.csv</td><td>45580638</td></tr></tbody></table></div>

# %%
df = pd.read_csv("/dbfs/mnt/dsip/data.csv", encoding = "ISO-8859-1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/2010 8:26</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
len(df.InvoiceNo.unique())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: 25900</div>

# %%
df.StockCode.unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: array([&#39;85123A&#39;, &#39;71053&#39;, &#39;84406B&#39;, ..., &#39;90214U&#39;, &#39;47591b&#39;, &#39;23843&#39;],
#       dtype=object)</div>

# %%
df.loc[df['StockCode'] == "85123A", 'Description'].iloc[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: &#39;WHITE HANGING HEART T-LIGHT HOLDER&#39;</div>

# %%
type(df.loc[df['StockCode'] == "85123A", 'Description'].iloc[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: str</div>

# %%
def create_correlation(initial_df):
  #creating the correlation between the stock code and the description
  corr = []
  for i in initial_df.StockCode.unique():
    corr.append({'StockCode': i, 'Description': initial_df.loc[df['StockCode'] == i, 'Description'].iloc[0]})
  return corr
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cor = create_correlation(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cor
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: [{&#39;StockCode&#39;: &#39;85123A&#39;, &#39;Description&#39;: &#39;WHITE HANGING HEART T-LIGHT HOLDER&#39;},
#  {&#39;StockCode&#39;: &#39;71053&#39;, &#39;Description&#39;: &#39;WHITE METAL LANTERN&#39;},
#  {&#39;StockCode&#39;: &#39;84406B&#39;, &#39;Description&#39;: &#39;CREAM CUPID HEARTS COAT HANGER&#39;},
#  {&#39;StockCode&#39;: &#39;84029G&#39;, &#39;Description&#39;: &#39;KNITTED UNION FLAG HOT WATER BOTTLE&#39;},
#  {&#39;StockCode&#39;: &#39;84029E&#39;, &#39;Description&#39;: &#39;RED WOOLLY HOTTIE WHITE HEART.&#39;},
#  {&#39;StockCode&#39;: &#39;22752&#39;, &#39;Description&#39;: &#39;SET 7 BABUSHKA NESTING BOXES&#39;},
#  {&#39;StockCode&#39;: &#39;21730&#39;, &#39;Description&#39;: &#39;GLASS STAR FROSTED T-LIGHT HOLDER&#39;},
#  {&#39;StockCode&#39;: &#39;22633&#39;, &#39;Description&#39;: &#39;HAND WARMER UNION JACK&#39;},
#  {&#39;StockCode&#39;: &#39;22632&#39;, &#39;Description&#39;: &#39;HAND WARMER RED POLKA DOT&#39;},
#  {&#39;StockCode&#39;: &#39;84879&#39;, &#39;Description&#39;: &#39;ASSORTED COLOUR BIRD ORNAMENT&#39;},
#  {&#39;StockCode&#39;: &#39;22745&#39;, &#39;Description&#39;: &#34;POPPY&#39;S PLAYHOUSE BEDROOM &#34;},
#  {&#39;StockCode&#39;: &#39;22748&#39;, &#39;Description&#39;: &#34;POPPY&#39;S PLAYHOUSE KITCHEN&#34;},
#  {&#39;StockCode&#39;: &#39;22749&#39;, &#39;Description&#39;: &#39;FELTCRAFT PRINCESS CHARLOTTE DOLL&#39;},
#  {&#39;StockCode&#39;: &#39;22310&#39;, &#39;Description&#39;: &#39;IVORY KNITTED MUG COSY &#39;},
#  {&#39;StockCode&#39;: &#39;84969&#39;, &#39;Description&#39;: &#39;BOX OF 6 ASSORTED COLOUR TEASPOONS&#39;},
#  {&#39;StockCode&#39;: &#39;22623&#39;, &#39;Description&#39;: &#39;BOX OF VINTAGE JIGSAW BLOCKS &#39;},
#  {&#39;StockCode&#39;: &#39;22622&#39;, &#39;Description&#39;: &#39;BOX OF VINTAGE ALPHABET BLOCKS&#39;},
#  {&#39;StockCode&#39;: &#39;21754&#39;, &#39;Description&#39;: &#39;HOME BUILDING BLOCK WORD&#39;},
#  {&#39;StockCode&#39;: &#39;21755&#39;, &#39;Description&#39;: &#39;LOVE BUILDING BLOCK WORD&#39;},
#  {&#39;StockCode&#39;: &#39;21777&#39;, &#39;Description&#39;: &#39;RECIPE BOX WITH METAL HEART&#39;},
#  {&#39;StockCode&#39;: &#39;48187&#39;, &#39;Description&#39;: &#39;DOORMAT NEW ENGLAND&#39;},
#  {&#39;StockCode&#39;: &#39;22960&#39;, &#39;Description&#39;: &#39;JAM MAKING SET WITH JARS&#39;},
#  {&#39;StockCode&#39;: &#39;22913&#39;, &#39;Description&#39;: &#39;RED COAT RACK PARIS FASHION&#39;},
#  {&#39;StockCode&#39;: &#39;22912&#39;, &#39;Description&#39;: &#39;YELLOW COAT RACK PARIS FASHION&#39;},
#  {&#39;StockCode&#39;: &#39;22914&#39;, &#39;Description&#39;: &#39;BLUE COAT RACK PARIS FASHION&#39;},
#  {&#39;StockCode&#39;: &#39;21756&#39;, &#39;Description&#39;: &#39;BATH BUILDING BLOCK WORD&#39;},
#  {&#39;StockCode&#39;: &#39;22728&#39;, &#39;Description&#39;: &#39;ALARM CLOCK BAKELIKE PINK&#39;},
#  {&#39;StockCode&#39;: &#39;22727&#39;, &#39;Description&#39;: &#39;ALARM CLOCK BAKELIKE RED &#39;},
#  {&#39;StockCode&#39;: &#39;22726&#39;, &#39;Description&#39;: &#39;ALARM CLOCK BAKELIKE GREEN&#39;},
#  {&#39;StockCode&#39;: &#39;21724&#39;, &#39;Description&#39;: &#39;PANDA AND BUNNIES STICKER SHEET&#39;},
#  {&#39;StockCode&#39;: &#39;21883&#39;, &#39;Description&#39;: &#39;STARS GIFT TAPE &#39;},
#  {&#39;StockCode&#39;: &#39;10002&#39;, &#39;Description&#39;: &#39;INFLATABLE POLITICAL GLOBE &#39;},
#  {&#39;StockCode&#39;: &#39;21791&#39;, &#39;Description&#39;: &#39;VINTAGE HEADS AND TAILS CARD GAME &#39;},
#  {&#39;StockCode&#39;: &#39;21035&#39;, &#39;Description&#39;: &#39;SET/2 RED RETROSPOT TEA TOWELS &#39;},
#  {&#39;StockCode&#39;: &#39;22326&#39;, &#39;Description&#39;: &#39;ROUND SNACK BOXES SET OF4 WOODLAND &#39;},
#  {&#39;StockCode&#39;: &#39;22629&#39;, &#39;Description&#39;: &#39;SPACEBOY LUNCH BOX &#39;},
#  {&#39;StockCode&#39;: &#39;22659&#39;, &#39;Description&#39;: &#39;LUNCH BOX I LOVE LONDON&#39;},
#  {&#39;StockCode&#39;: &#39;22631&#39;, &#39;Description&#39;: &#39;CIRCUS PARADE LUNCH BOX &#39;},
#  {&#39;StockCode&#39;: &#39;22661&#39;, &#39;Description&#39;: &#39;CHARLOTTE BAG DOLLY GIRL DESIGN&#39;},
#  {&#39;StockCode&#39;: &#39;21731&#39;, &#39;Description&#39;: &#39;RED TOADSTOOL LED NIGHT LIGHT&#39;},
#  {&#39;StockCode&#39;: &#39;22900&#39;, &#39;Description&#39;: &#39; SET 2 TEA TOWELS I LOVE LONDON &#39;},
#  {&#39;StockCode&#39;: &#39;21913&#39;, &#39;Description&#39;: &#39;VINTAGE SEASIDE JIGSAW PUZZLES&#39;},
#  {&#39;StockCode&#39;: &#39;22540&#39;, &#39;Description&#39;: &#39;MINI JIGSAW CIRCUS PARADE &#39;},
#  {&#39;StockCode&#39;: &#39;22544&#39;, &#39;Description&#39;: &#39;MINI JIGSAW SPACEBOY&#39;},
#  {&#39;StockCode&#39;: &#39;22492&#39;, &#39;Description&#39;: &#39;MINI PAINT SET VINTAGE &#39;},
#  {&#39;StockCode&#39;: &#39;POST&#39;, &#39;Description&#39;: &#39;POSTAGE&#39;},
#  {&#39;StockCode&#39;: &#39;22086&#39;, &#39;Description&#39;: &#34;PAPER CHAIN KIT 50&#39;S CHRISTMAS &#34;},
#  {&#39;StockCode&#39;: &#39;20679&#39;, &#39;Description&#39;: &#39;EDWARDIAN PARASOL RED&#39;},
#  {&#39;StockCode&#39;: &#39;37370&#39;, &#39;Description&#39;: &#39;RETRO COFFEE MUGS ASSORTED&#39;},
#  {&#39;StockCode&#39;: &#39;21871&#39;, &#39;Description&#39;: &#39;SAVE THE PLANET MUG&#39;},
#  {&#39;StockCode&#39;: &#39;21071&#39;, &#39;Description&#39;: &#39;VINTAGE BILLBOARD DRINK ME MUG&#39;},
#  {&#39;StockCode&#39;: &#39;21068&#39;, &#39;Description&#39;: &#39;VINTAGE BILLBOARD LOVE/HATE MUG&#39;},
#  {&#39;StockCode&#39;: &#39;82483&#39;, &#39;Description&#39;: &#39;WOOD 2 DRAWER CABINET WHITE FINISH&#39;},
#  {&#39;StockCode&#39;: &#39;82486&#39;, &#39;Description&#39;: &#39;WOOD S/3 CABINET ANT WHITE FINISH&#39;},
#  {&#39;StockCode&#39;: &#39;82482&#39;, &#39;Description&#39;: &#39;WOODEN PICTURE FRAME WHITE FINISH&#39;},
#  {&#39;StockCode&#39;: &#39;82494L&#39;, &#39;Description&#39;: &#39;WOODEN FRAME ANTIQUE WHITE &#39;},
#  {&#39;StockCode&#39;: &#39;21258&#39;, &#39;Description&#39;: &#39;VICTORIAN SEWING BOX LARGE&#39;},
#  {&#39;StockCode&#39;: &#39;22114&#39;, &#39;Description&#39;: &#39;HOT WATER BOTTLE TEA AND SYMPATHY&#39;},
#  {&#39;StockCode&#39;: &#39;21733&#39;, &#39;Description&#39;: &#39;RED HANGING HEART T-LIGHT HOLDER&#39;},
#  {&#39;StockCode&#39;: &#39;22386&#39;, &#39;Description&#39;: &#39;JUMBO BAG PINK POLKADOT&#39;},
#  {&#39;StockCode&#39;: &#39;85099C&#39;, &#39;Description&#39;: &#39;JUMBO  BAG BAROQUE BLACK WHITE&#39;},
#  {&#39;StockCode&#39;: &#39;21033&#39;, &#39;Description&#39;: &#39;JUMBO BAG CHARLIE AND LOLA TOYS&#39;},
#  {&#39;StockCode&#39;: &#39;20723&#39;, &#39;Description&#39;: &#39;STRAWBERRY CHARLOTTE BAG&#39;},
#  {&#39;StockCode&#39;: &#39;84997B&#39;, &#39;Description&#39;: &#39;RED 3 PIECE RETROSPOT CUTLERY SET&#39;},
#  {&#39;StockCode&#39;: &#39;84997C&#39;, &#39;Description&#39;: &#39;BLUE 3 PIECE POLKADOT CUTLERY SET&#39;},
#  {&#39;StockCode&#39;: &#39;21094&#39;, &#39;Description&#39;: &#39;SET/6 RED SPOTTY PAPER PLATES&#39;},
#  {&#39;StockCode&#39;: &#39;20725&#39;, &#39;Description&#39;: &#39;LUNCH BAG RED RETROSPOT&#39;},
#  {&#39;StockCode&#39;: &#39;21559&#39;, &#39;Description&#39;: &#39;STRAWBERRY LUNCH BOX WITH CUTLERY&#39;},
#  {&#39;StockCode&#39;: &#39;22352&#39;, &#39;Description&#39;: &#39;LUNCH BOX WITH CUTLERY RETROSPOT &#39;},
#  {&#39;StockCode&#39;: &#39;21212&#39;, &#39;Description&#39;: &#39;PACK OF 72 RETROSPOT CAKE CASES&#39;},
#  {&#39;StockCode&#39;: &#39;21975&#39;, &#39;Description&#39;: &#39;PACK OF 60 DINOSAUR CAKE CASES&#39;},
#  {&#39;StockCode&#39;: &#39;21977&#39;, &#39;Description&#39;: &#39;PACK OF 60 PINK PAISLEY CAKE CASES&#39;},
#  {&#39;StockCode&#39;: &#39;84991&#39;, &#39;Description&#39;: &#39;60 TEATIME FAIRY CAKE CASES&#39;},
#  {&#39;StockCode&#39;: &#39;84519A&#39;, &#39;Description&#39;: &#39;TOMATO CHAR

# %%
import random
def initial_values(rows):
    amounts = []
    for i in range(rows):
        amounts.append({'id':i, 'amount_value':round(random.uniform(0.00, 100000), 2)})
    return amounts
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
numbers_of_rows_in_dataset = 3000000
data = initial_values(numbers_of_rows_in_dataset)
ml_set = pd.DataFrame(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [{&#39;id&#39;: 0, &#39;amount_value&#39;: 8725.37},
#  {&#39;id&#39;: 1, &#39;amount_value&#39;: 90424.01},
#  {&#39;id&#39;: 2, &#39;amount_value&#39;: 97020.64},
#  {&#39;id&#39;: 3, &#39;amount_value&#39;: 72856.89},
#  {&#39;id&#39;: 4, &#39;amount_value&#39;: 17602.16},
#  {&#39;id&#39;: 5, &#39;amount_value&#39;: 53191.23},
#  {&#39;id&#39;: 130, &#39;amount_value&#39;: 81851.93},
#  {&#39;id&#39;: 131, &#39;amount_value&#39;: 76214.02},
#  {&#39;id&#39;: 132, &#39;amount_value&#39;: 45891.68},
#  {&#39;id&#39;: 133, &#39;amount_value&#39;: 81479.44},
#  {&#39;id&#39;: 134, &#39;amount_value&#39;: 49598.72},
#  {&#39;id&#39;: 135, &#39;amount_value&#39;: 41861.66},
#  {&#39;id&#39;: 136, &#39;amount_value&#39;: 67098.53},
#  {&#39;id&#39;: 137, &#39;amount_value&#39;: 66603.95},
#  {&#39;id&#39;: 138, &#39;amount_value&#39;: 65847.24},
#  {&#39;id&#39;: 139, &#

# %%
ml_set.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: (3000000, 2)</div>

# %%
ml_set['amount_currency'] = 'USD'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def random_channel(row):
    channel = ''
    rnd =  random.randrange(101)
    if  0 < rnd <= 10:
        channel = 'pos'
    elif 10 < rnd <= 50:
        channel = 'online'
    elif 51 < rnd <= 100:
        channel = 'virtual'
    else:
        channel = 'mobile'
    
    return channel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['channel'] = ml_set.apply(random_channel, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set.channel.unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: array([&#39;online&#39;, &#39;virtual&#39;, &#39;pos&#39;, &#39;mobile&#39;], dtype=object)</div>

# %%
def deviceDetails_browser(row):
    browser = ''
    rnd =  random.randrange(101)
    if  0 < rnd <= 10:
        browser = 'mozilla'
    elif 10 < rnd <= 50:
        browser = 'chrome'
    elif 51 < rnd <= 100:
        browser = 'edge'
    else:
        browser = 'chromio'
    
    return browser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['deviceDetails_browser'] = ml_set.apply(deviceDetails_browser, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def deviceDetails_device(row):
    device = ''
    rnd =  random.randrange(101)
    if  0 < rnd <= 10:
        device = 'mobile'
    elif 10 < rnd <= 50:
        device = 'pc'
    else:
        device = 'pos'
    
    return device
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['deviceDetails_device'] = ml_set.apply(deviceDetails_device, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import socket
import struct
def deviceDetails_deviceIp(row):
    ip = socket.inet_ntoa(struct.pack('>I', random.randint(1, 0xffffffff)))
    return ip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['deviceDetails_deviceIp'] = ml_set.apply(deviceDetails_deviceIp, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import string
def merchantRefTransactionId(row):
    letters = string.digits
    return ''.join(random.choice(letters) for i in range(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['merchantRefTransactionId'] = ml_set.apply(merchantRefTransactionId, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def paymentMethod_apmType(row):
    amp = ''
    rnd =  random.randrange(101)
    if  0 < rnd <= 10:
        amp = 'chip'
    elif 10 < rnd <= 50:
        amp = 'magstripe '
    else:
        amp = 'nfcc'
    
    return amp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_apmType'] = ml_set.apply(paymentMethod_apmType, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import string
def paymentMethod_cardNumber(row):
    card_number = ''
    numbers = string.digits
    for part in range(4):
        card_number += ''.join((random.choice(numbers) for i in range(4))) + '-'
    return card_number[:-1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_cardNumber'] = ml_set.apply(paymentMethod_cardNumber, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def paymentMethod_cardType(row):
    card_type = ''
    rnd =  random.randrange(201)
    if  0 < rnd <= 10:
        card_type = 'MasterCard'
    elif 10 < rnd <= 50:
        card_type = 'Visa '
    elif 51 < rnd <= 100:
        card_type = 'Discover '
    elif 51 < rnd <= 100:
        card_type = 'JCB'
    else:
        card_type = 'American Express'
    
    return card_type
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_cardType'] = ml_set.apply(paymentMethod_cardType, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def paymentMethod_cardSubType(row):
    card_subtype = ''
    rnd =  random.randrange(201)
    if  0 < rnd <= 10:
        card_subtype = 'Secured'
    elif 10 < rnd <= 50:
        card_subtype = 'Prepaid '
    elif 51 < rnd <= 100:
        card_subtype = 'Business '
    elif 51 < rnd <= 100:
        card_subtype = 'Student'
    else:
        card_subtype = 'Generic'
    
    return card_subtype
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_cardSubType'] = ml_set.apply(paymentMethod_cardSubType, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import string
def paymentMethod_cvv(row):
    numbers = string.digits
    return ''.join((random.choice(numbers) for i in range(3)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_cvv'] = ml_set.apply(paymentMethod_cvv, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def paymentMethod_encodedPaymentToken(row):
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(8))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_encodedPaymentToken'] = ml_set.apply(paymentMethod_encodedPaymentToken, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>amount_value</th>
#       <th>amount_currency</th>
#       <th>channel</th>
#       <th>deviceDetails_browser</th>
#       <th>deviceDetails_device</th>
#       <th>deviceDetails_deviceIp</th>
#       <th>merchantRefTransactionId</th>
#       <th>paymentMethod_apmType</th>
#       <th>paymentMethod_cardNumber</th>
#       <th>paymentMethod_cardType</th>
#       <th>paymentMethod_cardSubType</th>
#       <th>paymentMethod_cvv</th>
#       <th>paymentMethod_encodedPaymentToken</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>52674.11</td>
#       <td>USD</td>
#       <td>online</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>49.163.133.162</td>
#       <td>8068408692</td>
#       <td>magstripe</td>
#       <td>2385-5404-2091-8967</td>
#       <td>Discover</td>
#       <td>Generic</td>
#       <td>947</td>
#       <td>djKIQXjZ</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>85296.01</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>chrome</td>
#       <td>pos</td>
#       <td>160.65.195.137</td>
#       <td>4377079229</td>
#       <td>magstripe</td>
#       <td>9116-8339-7115-5513</td>
#       <td>American Express</td>
#       <td>Prepaid</td>
#       <td>942</td>
#       <td>UnGsLyHj</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>90216.63</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>chrome</td>
#       <td>pc</td>
#       <td>161.195.45.60</td>
#       <td>9656269727</td>
#       <td>magstripe</td>
#       <td>3602-3265-6476-3263</td>
#       <td>Discover</td>
#       <td>Secured</td>
#       <td>838</td>
#       <td>iDljPjZZ</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>71377.42</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>204.88.205.7</td>
#       <td>1612067815</td>
#       <td>magstripe</td>
#       <td>9300-0028-9239-8479</td>
#       <td>American Express</td>
#       <td>Generic</td>
#       <td>071</td>
#       <td>xqbytldy</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>45932.43</td>
#       <td>USD</td>
#       <td>pos</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>226.121.147.17</td>
#       <td>0421966816</td>
#       <td>nfcc</td>
#       <td>7572-4620-6384-7848</td>
#       <td>American Express</td>
#       <td>Generic</td>
#       <td>735</td>
#       <td>RHKDHTUd</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from random import randrange

def paymentMethod_expiryMonth(row):
    return randrange(12)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_expiryMonth'] = ml_set.apply(paymentMethod_expiryMonth, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from random import randrange

def paymentMethod_expiryYear(row):
    start_year = randrange(2018,2020)
    return randrange(start_year, start_year + 10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_expiryYear'] = ml_set.apply(paymentMethod_expiryYear, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>amount_value</th>
#       <th>amount_currency</th>
#       <th>channel</th>
#       <th>deviceDetails_browser</th>
#       <th>deviceDetails_device</th>
#       <th>deviceDetails_deviceIp</th>
#       <th>merchantRefTransactionId</th>
#       <th>paymentMethod_apmType</th>
#       <th>paymentMethod_cardNumber</th>
#       <th>paymentMethod_cardType</th>
#       <th>paymentMethod_cardSubType</th>
#       <th>paymentMethod_cvv</th>
#       <th>paymentMethod_encodedPaymentToken</th>
#       <th>paymentMethod_expiryMonth</th>
#       <th>paymentMethod_expiryYear</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>52674.11</td>
#       <td>USD</td>
#       <td>online</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>49.163.133.162</td>
#       <td>8068408692</td>
#       <td>magstripe</td>
#       <td>2385-5404-2091-8967</td>
#       <td>Discover</td>
#       <td>Generic</td>
#       <td>947</td>
#       <td>djKIQXjZ</td>
#       <td>8</td>
#       <td>2028</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>85296.01</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>chrome</td>
#       <td>pos</td>
#       <td>160.65.195.137</td>
#       <td>4377079229</td>
#       <td>magstripe</td>
#       <td>9116-8339-7115-5513</td>
#       <td>American Express</td>
#       <td>Prepaid</td>
#       <td>942</td>
#       <td>UnGsLyHj</td>
#       <td>1</td>
#       <td>2020</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>90216.63</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>chrome</td>
#       <td>pc</td>
#       <td>161.195.45.60</td>
#       <td>9656269727</td>
#       <td>magstripe</td>
#       <td>3602-3265-6476-3263</td>
#       <td>Discover</td>
#       <td>Secured</td>
#       <td>838</td>
#       <td>iDljPjZZ</td>
#       <td>0</td>
#       <td>2024</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>71377.42</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>204.88.205.7</td>
#       <td>1612067815</td>
#       <td>magstripe</td>
#       <td>9300-0028-9239-8479</td>
#       <td>American Express</td>
#       <td>Generic</td>
#       <td>071</td>
#       <td>xqbytldy</td>
#       <td>7</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>45932.43</td>
#       <td>USD</td>
#       <td>pos</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>226.121.147.17</td>
#       <td>0421966816</td>
#       <td>nfcc</td>
#       <td>7572-4620-6384-7848</td>
#       <td>American Express</td>
#       <td>Generic</td>
#       <td>735</td>
#       <td>RHKDHTUd</td>
#       <td>6</td>
#       <td>2026</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ml_set.to_csv('ml_datasert.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
