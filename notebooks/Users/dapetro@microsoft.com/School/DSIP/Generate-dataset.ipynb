# %%
import pandas as pd
import random
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# columns = ['id','amount_currency','amount_value','channel','deviceDetails_browser',
#            'deviceDetails_device','deviceDetails_deviceIp','merchantRefTransactionId','paymentMethod_apmType',
#            'paymentMethod_cardNumber','paymentMethod_cardSubType','paymentMethod_cardType','paymentMethod_cvv',
#            'paymentMethod_encodedPaymentToken','paymentMethod_expiryMonth','paymentMethod_expiryYear',
#            'shopperDetails_address_addressLine1','shopperDetails_address_addressLine2',
#            'shopperDetails_address_city','shopperDetails_address_country','shopperDetails_address_postalCode',
#            'shopperDetails_address_state','shopperDetails_email','shopperDetails_firstName','shopperDetails_lastName',
#            'shopperDetails_phoneNumber','shopperDetails_shopperKey']

columns = ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls "/mnt/dsip"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/dsip/data.csv</td><td>data.csv</td><td>45580638</td></tr></tbody></table></div>

# %%
df = pd.read_csv("/dbfs/mnt/dsip/data.csv", encoding = "ISO-8859-1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/2010 8:26</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>536365</td>
#       <td>22752</td>
#       <td>SET 7 BABUSHKA NESTING BOXES</td>
#       <td>2</td>
#       <td>12/1/2010 8:26</td>
#       <td>7.65</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>536365</td>
#       <td>21730</td>
#       <td>GLASS STAR FROSTED T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/2010 8:26</td>
#       <td>4.25</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>536366</td>
#       <td>22633</td>
#       <td>HAND WARMER UNION JACK</td>
#       <td>6</td>
#       <td>12/1/2010 8:28</td>
#       <td>1.85</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>536366</td>
#       <td>22632</td>
#       <td>HAND WARMER RED POLKA DOT</td>
#       <td>6</td>
#       <td>12/1/2010 8:28</td>
#       <td>1.85</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>536367</td>
#       <td>84879</td>
#       <td>ASSORTED COLOUR BIRD ORNAMENT</td>
#       <td>32</td>
#       <td>12/1/2010 8:34</td>
#       <td>1.69</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>536367</td>
#       <td>22745</td>
#       <td>POPPY'S PLAYHOUSE BEDROOM</td>
#       <td>6</td>
#       <td>12/1/2010 8:34</td>
#       <td>2.10</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>536367</td>
#       <td>22748</td>
#       <td>POPPY'S PLAYHOUSE KITCHEN</td>
#       <td>6</td>
#       <td>12/1/2010 8:34</td>
#       <td>2.10</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>536367</td>
#       <td>22749</td>
#       <td>FELTCRAFT PRINCESS CHARLOTTE DOLL</td>
#       <td>8</td>
#       <td>12/1/2010 8:34</td>
#       <td>3.75</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>536367</td>
#       <td>22310</td>
#       <td>IVORY KNITTED MUG COSY</td>
#       <td>6</td>
#       <td>12/1/2010 8:34</td>
#       <td>1.65</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>536367</td>
#       <td>84969</td>
#       <td>BOX OF 6 ASSORTED COLOUR TEASPOONS</td>
#       <td>6</td>
#       <td>12/1/2010 8:34</td>
#       <td>4.25</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>536367</td>
#       <td>22623</td>
#       <td>BOX OF VINTAGE JIGSAW BLOCKS</td>
#       <td>3</td>
#       <td>12/1/2010 8:34</td>
#       <td>4.95</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>536367</td>
#       <td>22622</td>
#       <td>BOX OF VINTAGE ALPHABET BLOCKS</td>
#       <td>2</td>
#       <td>12/1/2010 8:34</td>
#       <td>9.95</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>536367</td>
#       <td>21754</td>
#       <td>HOME BUILDING BLOCK WORD</td>
#       <td>3</td>
#       <td>12/1/2010 8:34</td>
#       <td>5.95</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>536367</td>
#       <td>21755</td>
#       <td>LOVE BUILDING BLOCK WORD</td>
#       <td>3</td>
#       <td>12/1/2010 8:34</td>
#       <td>5.95</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>536367</td>
#       <td>21777</td>
#       <td>RECIPE BOX WITH METAL HEART</td>
#       <td>4</td>
#       <td>12/1/2010 8:34</td>
#       <td>7.95</td>
#       <td>13047.0</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
len(df.InvoiceNo.unique())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 25900</div>

# %%
df.StockCode.unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: array([&#39;85123A&#39;, &#39;71053&#39;, &#39;84406B&#39;, ..., &#39;90214U&#39;, &#39;47591b&#39;, &#39;23843&#39;],
#       dtype=object)</div>

# %%
df.loc[df['StockCode'] == "85123A", 'Description'].iloc[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: &#39;WHITE HANGING HEART T-LIGHT HOLDER&#39;</div>

# %%
type(df.loc[df['StockCode'] == "85123A", 'Description'].iloc[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: str</div>

# %%
def create_correlation(initial_df):
  #creating the correlation between the stock code and the description
  corr = []
  for i in initial_df.StockCode.unique():
    corr.append({'StockCode': i, 'Description': initial_df.loc[df['StockCode'] == i, 'Description'].iloc[0]})
  return corr
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cor = create_correlation(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cor
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [{&#39;StockCode&#39;: &#39;85123A&#39;, &#39;Description&#39;: &#39;WHITE HANGING HEART T-LIGHT HOLDER&#39;},
#  {&#39;StockCode&#39;: &#39;71053&#39;, &#39;Description&#39;: &#39;WHITE METAL LANTERN&#39;},
#  {&#39;StockCode&#39;: &#39;84406B&#39;, &#39;Description&#39;: &#39;CREAM CUPID HEARTS COAT HANGER&#39;},
#  {&#39;StockCode&#39;: &#39;84029G&#39;, &#39;Description&#39;: &#39;KNITTED UNION FLAG HOT WATER BOTTLE&#39;},
#  {&#39;StockCode&#39;: &#39;84029E&#39;, &#39;Description&#39;: &#39;RED WOOLLY HOTTIE WHITE HEART.&#39;},
#  {&#39;StockCode&#39;: &#39;22752&#39;, &#39;Description&#39;: &#39;SET 7 BABUSHKA NESTING BOXES&#39;},
#  {&#39;StockCode&#39;: &#39;21730&#39;, &#39;Description&#39;: &#39;GLASS STAR FROSTED T-LIGHT HOLDER&#39;},
#  {&#39;StockCode&#39;: &#39;22633&#39;, &#39;Description&#39;: &#39;HAND WARMER UNION JACK&#39;},
#  {&#39;StockCode&#39;: &#39;22632&#39;, &#39;Description&#39;: &#39;HAND WARMER RED POLKA DOT&#39;},
#  {&#39;StockCode&#39;: &#39;84879&#39;, &#39;Description&#39;: &#39;ASSORTED COLOUR BIRD ORNAMENT&#39;},
#  {&#39;StockCode&#39;: &#39;22745&#39;, &#39;Description&#39;: &#34;POPPY&#39;S PLAYHOUSE BEDROOM &#34;},
#  {&#39;StockCode&#39;: &#39;22748&#39;, &#39;Description&#39;: &#34;POPPY&#39;S PLAYHOUSE KITCHEN&#34;},
#  {&#39;StockCode&#39;: &#39;22749&#39;, &#39;Description&#39;: &#39;FELTCRAFT PRINCESS CHARLOTTE DOLL&#39;},
#  {&#39;StockCode&#39;: &#39;22310&#39;, &#39;Description&#39;: &#39;IVORY KNITTED MUG COSY &#39;},
#  {&#39;StockCode&#39;: &#39;84969&#39;, &#39;Description&#39;: &#39;BOX OF 6 ASSORTED COLOUR TEASPOONS&#39;},
#  {&#39;StockCode&#39;: &#39;22623&#39;, &#39;Description&#39;: &#39;BOX OF VINTAGE JIGSAW BLOCKS &#39;},
#  {&#39;StockCode&#39;: &#39;22622&#39;, &#39;Description&#39;: &#39;BOX OF VINTAGE ALPHABET BLOCKS&#39;},
#  {&#39;StockCode&#39;: &#39;21754&#39;, &#39;Description&#39;: &#39;HOME BUILDING BLOCK WORD&#39;},
#  {&#39;StockCode&#39;: &#39;21755&#39;, &#39;Description&#39;: &#39;LOVE BUILDING BLOCK WORD&#39;},
#  {&#39;StockCode&#39;: &#39;21777&#39;, &#39;Description&#39;: &#39;RECIPE BOX WITH METAL HEART&#39;},
#  {&#39;StockCode&#39;: &#39;48187&#39;, &#39;Description&#39;: &#39;DOORMAT NEW ENGLAND&#39;},
#  {&#39;StockCode&#39;: &#39;22960&#39;, &#39;Description&#39;: &#39;JAM MAKING SET WITH JARS&#39;},
#  {&#39;StockCode&#39;: &#39;22913&#39;, &#39;Description&#39;: &#39;RED COAT RACK PARIS FASHION&#39;},
#  {&#39;StockCode&#39;: &#39;22912&#39;, &#39;Description&#39;: &#39;YELLOW COAT RACK PARIS FASHION&#39;},
#  {&#39;StockCode&#39;: &#39;22914&#39;, &#39;Description&#39;: &#39;BLUE COAT RACK PARIS FASHION&#39;},
#  {&#39;StockCode&#39;: &#39;21756&#39;, &#39;Description&#39;: &#39;BATH BUILDING BLOCK WORD&#39;},
#  {&#39;StockCode&#39;: &#39;22728&#39;, &#39;Description&#39;: &#39;ALARM CLOCK BAKELIKE PINK&#39;},
#  {&#39;StockCode&#39;: &#39;22727&#39;, &#39;Description&#39;: &#39;ALARM CLOCK BAKELIKE RED &#39;},
#  {&#39;StockCode&#39;: &#39;22726&#39;, &#39;Description&#39;: &#39;ALARM CLOCK BAKELIKE GREEN&#39;},
#  {&#39;StockCode&#39;: &#39;21724&#39;, &#39;Description&#39;: &#39;PANDA AND BUNNIES STICKER SHEET&#39;},
#  {&#39;StockCode&#39;: &#39;21883&#39;, &#39;Description&#39;: &#39;STARS GIFT TAPE &#39;},
#  {&#39;StockCode&#39;: &#39;10002&#39;, &#39;Description&#39;: &#39;INFLATABLE POLITICAL GLOBE &#39;},
#  {&#39;StockCode&#39;: &#39;21791&#39;, &#39;Description&#39;: &#39;VINTAGE HEADS AND TAILS CARD GAME &#39;},
#  {&#39;StockCode&#39;: &#39;21035&#39;, &#39;Description&#39;: &#39;SET/2 RED RETROSPOT TEA TOWELS &#39;},
#  {&#39;StockCode&#39;: &#39;22326&#39;, &#39;Description&#39;: &#39;ROUND SNACK BOXES SET OF4 WOODLAND &#39;},
#  {&#39;StockCode&#39;: &#39;22629&#39;, &#39;Description&#39;: &#39;SPACEBOY LUNCH BOX &#39;},
#  {&#39;StockCode&#39;: &#39;22659&#39;, &#39;Description&#39;: &#39;LUNCH BOX I LOVE LONDON&#39;},
#  {&#39;StockCode&#39;: &#39;22631&#39;, &#39;Description&#39;: &#39;CIRCUS PARADE LUNCH BOX &#39;},
#  {&#39;StockCode&#39;: &#39;22661&#39;, &#39;Description&#39;: &#39;CHARLOTTE BAG DOLLY GIRL DESIGN&#39;},
#  {&#39;StockCode&#39;: &#39;21731&#39;, &#39;Description&#39;: &#39;RED TOADSTOOL LED NIGHT LIGHT&#39;},
#  {&#39;StockCode&#39;: &#39;22900&#39;, &#39;Description&#39;: &#39; SET 2 TEA TOWELS I LOVE LONDON &#39;},
#  {&#39;StockCode&#39;: &#39;21913&#39;, &#39;Description&#39;: &#39;VINTAGE SEASIDE JIGSAW PUZZLES&#39;},
#  {&#39;StockCode&#39;: &#39;22540&#39;, &#39;Description&#39;: &#39;MINI JIGSAW CIRCUS PARADE &#39;},
#  {&#39;StockCode&#39;: &#39;22544&#39;, &#39;Description&#39;: &#39;MINI JIGSAW SPACEBOY&#39;},
#  {&#39;StockCode&#39;: &#39;22492&#39;, &#39;Description&#39;: &#39;MINI PAINT SET VINTAGE &#39;},
#  {&#39;StockCode&#39;: &#39;POST&#39;, &#39;Description&#39;: &#39;POSTAGE&#39;},
#  {&#39;StockCode&#39;: &#39;22086&#39;, &#39;Description&#39;: &#34;PAPER CHAIN KIT 50&#39;S CHRISTMAS &#34;},
#  {&#39;StockCode&#39;: &#39;20679&#39;, &#39;Description&#39;: &#39;EDWARDIAN PARASOL RED&#39;},
#  {&#39;StockCode&#39;: &#39;37370&#39;, &#39;Description&#39;: &#39;RETRO COFFEE MUGS ASSORTED&#39;},
#  {&#39;StockCode&#39;: &#39;21871&#39;, &#39;Description&#39;: &#39;SAVE THE PLANET MUG&#39;},
#  {&#39;StockCode&#39;: &#39;21071&#39;, &#39;Description&#39;: &#39;VINTAGE BILLBOARD DRINK ME MUG&#39;},
#  {&#39;StockCode&#39;: &#39;21068&#39;, &#39;Description&#39;: &#39;VINTAGE BILLBOARD LOVE/HATE MUG&#39;},
#  {&#39;StockCode&#39;: &#39;82483&#39;, &#39;Description&#39;: &#39;WOOD 2 DRAWER CABINET WHITE FINISH&#39;},
#  {&#39;StockCode&#39;: &#39;82486&#39;, &#39;Description&#39;: &#39;WOOD S/3 CABINET ANT WHITE FINISH&#39;},
#  {&#39;StockCode&#39;: &#39;82482&#39;, &#39;Description&#39;: &#39;WOODEN PICTURE FRAME WHITE FINISH&#39;},
#  {&#39;StockCode&#39;: &#39;82494L&#39;, &#39;Description&#39;: &#39;WOODEN FRAME ANTIQUE WHITE &#39;},
#  {&#39;StockCode&#39;: &#39;21258&#39;, &#39;Description&#39;: &#39;VICTORIAN SEWING BOX LARGE&#39;},
#  {&#39;StockCode&#39;: &#39;22114&#39;, &#39;Description&#39;: &#39;HOT WATER BOTTLE TEA AND SYMPATHY&#39;},
#  {&#39;StockCode&#39;: &#39;21733&#39;, &#39;Description&#39;: &#39;RED HANGING HEART T-LIGHT HOLDER&#39;},
#  {&#39;StockCode&#39;: &#39;22386&#39;, &#39;Description&#39;: &#39;JUMBO BAG PINK POLKADOT&#39;},
#  {&#39;StockCode&#39;: &#39;85099C&#39;, &#39;Description&#39;: &#39;JUMBO  BAG BAROQUE BLACK WHITE&#39;},
#  {&#39;StockCode&#39;: &#39;21033&#39;, &#39;Description&#39;: &#39;JUMBO BAG CHARLIE AND LOLA TOYS&#39;},
#  {&#39;StockCode&#39;: &#39;20723&#39;, &#39;Description&#39;: &#39;STRAWBERRY CHARLOTTE BAG&#39;},
#  {&#39;StockCode&#39;: &#39;84997B&#39;, &#39;Description&#39;: &#39;RED 3 PIECE RETROSPOT CUTLERY SET&#39;},
#  {&#39;StockCode&#39;: &#39;84997C&#39;, &#39;Description&#39;: &#39;BLUE 3 PIECE POLKADOT CUTLERY SET&#39;},
#  {&#39;StockCode&#39;: &#39;21094&#39;, &#39;Description&#39;: &#39;SET/6 RED SPOTTY PAPER PLATES&#39;},
#  {&#39;StockCode&#39;: &#39;20725&#39;, &#39;Description&#39;: &#39;LUNCH BAG RED RETROSPOT&#39;},
#  {&#39;StockCode&#39;: &#39;21559&#39;, &#39;Description&#39;: &#39;STRAWBERRY LUNCH BOX WITH CUTLERY&#39;},
#  {&#39;StockCode&#39;: &#39;22352&#39;, &#39;Description&#39;: &#39;LUNCH BOX WITH CUTLERY RETROSPOT &#39;},
#  {&#39;StockCode&#39;: &#39;21212&#39;, &#39;Description&#39;: &#39;PACK OF 72 RETROSPOT CAKE CASES&#39;},
#  {&#39;StockCode&#39;: &#39;21975&#39;, &#39;Description&#39;: &#39;PACK OF 60 DINOSAUR CAKE CASES&#39;},
#  {&#39;StockCode&#39;: &#39;21977&#39;, &#39;Description&#39;: &#39;PACK OF 60 PINK PAISLEY CAKE CASES&#39;},
#  {&#39;StockCode&#39;: &#39;84991&#39;, &#39;Description&#39;: &#39;60 TEATIME FAIRY CAKE CASES&#39;},
#  {&#39;StockCode&#39;: &#39;84519A&#39;, &#39;Description&#39;: &#39;TOMATO CHARL

# %%
def create_correlation_price(initial_df):
  #creating the correlation between the stock code and the description
  corr = []
  for i in initial_df.StockCode.unique():
    corr.append({'StockCode': i, 'UnitPrice': initial_df.loc[df['StockCode'] == i, 'UnitPrice'].iloc[0]})
  return corr
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
corr_price = create_correlation_price(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
corr_price
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [{&#39;StockCode&#39;: &#39;85123A&#39;, &#39;UnitPrice&#39;: 2.55},
#  {&#39;StockCode&#39;: &#39;71053&#39;, &#39;UnitPrice&#39;: 3.39},
#  {&#39;StockCode&#39;: &#39;84406B&#39;, &#39;UnitPrice&#39;: 2.75},
#  {&#39;StockCode&#39;: &#39;84029G&#39;, &#39;UnitPrice&#39;: 3.39},
#  {&#39;StockCode&#39;: &#39;84029E&#39;, &#39;UnitPrice&#39;: 3.39},
#  {&#39;StockCode&#39;: &#39;22752&#39;, &#39;UnitPrice&#39;: 7.65},
#  {&#39;StockCode&#39;: &#39;21730&#39;, &#39;UnitPrice&#39;: 4.25},
#  {&#39;StockCode&#39;: &#39;22633&#39;, &#39;UnitPrice&#39;: 1.85},
#  {&#39;StockCode&#39;: &#39;22632&#39;, &#39;UnitPrice&#39;: 1.85},
#  {&#39;StockCode&#39;: &#39;84879&#39;, &#39;UnitPrice&#39;: 1.69},
#  {&#39;StockCode&#39;: &#39;22745&#39;, &#39;UnitPrice&#39;: 2.1},
#  {&#39;StockCode&#39;: &#39;22748&#39;, &#39;UnitPrice&#39;: 2.1},
#  {&#39;StockCode&#39;: &#39;22749&#39;, &#39;UnitPrice&#39;: 3.75},
#  {&#39;StockCode&#39;: &#39;22310&#39;, &#39;UnitPrice&#39;: 1.65},
#  {&#39;StockCode&#39;: &#39;84969&#39;, &#39;UnitPrice&#39;: 4.25},
#  {&#39;StockCode&#39;: &#39;22623&#39;, &#39;UnitPrice&#39;: 4.95},
#  {&#39;StockCode&#39;: &#39;22622&#39;, &#39;UnitPrice&#39;: 9.95},
#  {&#39;StockCode&#39;: &#39;21754&#39;, &#39;UnitPrice&#39;: 5.95},
#  {&#39;StockCode&#39;: &#39;21755&#39;, &#39;UnitPrice&#39;: 5.95},
#  {&#39;StockCode&#39;: &#39;21777&#39;, &#39;UnitPrice&#39;: 7.95},
#  {&#39;StockCode&#39;: &#39;48187&#39;, &#39;UnitPrice&#39;: 7.95},
#  {&#39;StockCode&#39;: &#39;22960&#39;, &#39;UnitPrice&#39;: 4.25},
#  {&#39;StockCode&#39;: &#39;22913&#39;, &#39;UnitPrice&#39;: 4.95},
#  {&#39;StockCode&#39;: &#39;22912&#39;, &#39;UnitPrice&#39;: 4.95},
#  {&#39;StockCode&#39;: &#39;22914&#39;, &#39;UnitPrice&#39;: 4.95},
#  {&#39;StockCode&#39;: &#39;21756&#39;, &#39;UnitPrice&#39;: 5.95},
#  {&#39;StockCode&#39;: &#39;22728&#39;, &#39;UnitPrice&#39;: 3.75},
#  {&#39;StockCode&#39;: &#39;22727&#39;, &#39;UnitPrice&#39;: 3.75},
#  {&#39;StockCode&#39;: &#39;22726&#39;, &#39;UnitPrice&#39;: 3.75},
#  {&#39;StockCode&#39;: &#39;21724&#39;, &#39;UnitPrice&#39;: 0.85},
#  {&#39;StockCode&#39;: &#39;21883&#39;, &#39;UnitPrice&#39;: 0.65},
#  {&#39;StockCode&#39;: &#39;10002&#39;, &#39;UnitPrice&#39;: 0.85},
#  {&#39;StockCode&#39;: &#39;21791&#39;, &#39;UnitPrice&#39;: 1.25},
#  {&#39;StockCode&#39;: &#39;21035&#39;, &#39;UnitPrice&#39;: 2.95},
#  {&#39;StockCode&#39;: &#39;22326&#39;, &#39;UnitPrice&#39;: 2.95},
#  {&#39;StockCode&#39;: &#39;22629&#39;, &#39;UnitPrice&#39;: 1.95},
#  {&#39;StockCode&#39;: &#39;22659&#39;, &#39;UnitPrice&#39;: 1.95},
#  {&#39;StockCode&#39;: &#39;22631&#39;, &#39;UnitPrice&#39;: 1.95},
#  {&#39;StockCode&#39;: &#39;22661&#39;, &#39;UnitPrice&#39;: 0.85},
#  {&#39;StockCode&#39;: &#39;21731&#39;, &#39;UnitPrice&#39;: 1.65},
#  {&#39;StockCode&#39;: &#39;22900&#39;, &#39;UnitPrice&#39;: 2.95},
#  {&#39;StockCode&#39;: &#39;21913&#39;, &#39;UnitPrice&#39;: 3.75},
#  {&#39;StockCode&#39;: &#39

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: 4070</div>

# %%
import random
def initial_values(rows):
    amounts = []
    for i in range(rows):
        amounts.append({'id':i, 'amount_value':round(random.uniform(0.00, 100000), 2)})
    return amounts
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
numbers_of_rows_in_dataset = 3000000
data = initial_values(numbers_of_rows_in_dataset)
ml_set = pd.DataFrame(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [{&#39;id&#39;: 0, &#39;amount_value&#39;: 30045.08},
#  {&#39;id&#39;: 1, &#39;amount_value&#39;: 77648.71},
#  {&#39;id&#39;: 2, &#39;amount_value&#39;: 75037.06},
#  {&#39;id&#39;: 3, &#39;amount_value&#39;: 76521.92},
#  {&#39;id&#39;: 4, &#39;amount_value&#39;: 92287.01},
#  {&#39;id&#39;: 5, &#39;amount_value&#39;: 90982.86},
#  {&#39;id&#39;: 6, &#39;amount_value&#39;: 93579.51},
#  {&#39;id&#39;: 7, &#39;amount_value&#39;: 46664.83},
#  {&#39;id&#39;: 8, &#39;amount_value&#39;: 24639.93},
#  {&#39;id&#39;: 9, &#39;amount_value&#39;: 98223.66},
#  {&#39;id&#39;: 10, &#39;amount_value&#39;: 17897.31},
#  {&#39;id&#39;: 11, &#39;amount_value&#39;: 81911.53},
#  {&#39;id&#39;: 12, &#39;amount_value&#39;: 83624.93},
#  {&#39;id&#39;: 13, &#39;amount_value&#39;: 41178.67},
#  {&#39;id&#39;: 14, &#39;amount_value&#39;: 36882.1},
#  {&#39;id&#39;: 15, &#39;amount_value&#39;: 8127.93},
#  {&#39;id&#39;: 16, &#39;amount_value&#39;: 19495.1},
#  {&#39;id&#39;: 17, &#39;amount_value&#39;: 47225.96},
#  {&#39;id&#39;: 18, &#39;amount_value&#39;: 56086.96},
#  {&#39;id&#39;: 19, &#39;amount_value&#39;: 55904.97},
#  {&#39;id&#39;: 20, &#39;amount_value&#39;: 61918.42},
#  {&#39;id&#39;: 21, &#39;amount_value&#39;: 69439.67},
#  {&#39;id&#39;: 22, &#39;amount_value&#39;: 82895.68},
#  {&#39;id&#39;: 23, &#39;amount_value&#39;: 44191.91},
#  {&#39;id&#39;: 24, &#39;amount_value&#39;: 40595.23},
#  {&#39;id&#39;: 25, &#39;amount_value&#39;: 23561.47},
#  {&#39;id&#39;: 26, &#39;amount_value&#39;: 944.14},
#  {&#39;id&#39;: 27, &#39;amount_value&#39;: 4040.92},
#  {&#39;id&#39;: 28, &#39;amount_value&#39;: 18294.39},
#  {&#39;id&#39;: 29, &#39;amount_value&#39;: 92077.58},
#  {&#39;id&#39;: 30, &#39;amount_value&#39;: 93146.55},
#  {&#39;id&#39;: 31, &#39;amount_value&#39;: 38528.58},
#  {&#39;id&#39;: 32, &#39;amount_value&#39;: 30301.67},
#  {&#39;id&#39;: 33, &#39;amount_value&#39;: 47517.06},
#  {&#39;id&#39;: 34, &#39;amount_value&#39;: 26471.36},
#  {&#39;id&#39;: 121, &#39;amount_value&#39;: 84893.08},
#  {&#39;id&#39;: 122, &#39;amount_value&#39;: 39336.16},
#  {&#39;id&#39;: 123, &#39;amount_value&#39;: 31590.22},
#  {&#39;id&#39;: 124, &#39;amount_value&#39;: 56442.62},
#  {&#39;id&#39;: 125, &#39;amount_value&#39;: 22161.51},
#  {&#39;id&#39;: 126, &#39;amount_value&#39;: 39507.02},
#  {&#39;id&#39;: 127, &#39;amount_value&#39;: 7398.51},
#  {&#39;id&#39;: 128, &#39;amount_value&#39;: 79736.4},
#  {&#39;id&#39;: 129, &#39;amount_value&#39;: 94484.79},
#  {&#39;id&#39;: 130, &#39;amount_value&#39;: 8453.28},
#  {&#39;id&#39;: 131, &#39;amount_value&#39;: 47358.22},
#  {&#39;id&#39;: 132, &#39;amount_value&#39;: 64322.23},
#  {&#39;id&#39;: 133, &#39;amount_value&#39;: 62973.44},
#  {&#39;id&#39;: 134, &#39;amount_value&#39;: 960.02},
#  {&#39;id&#39;: 135, &#39;amount_value&#39;: 13223.4},
#  {&#39;id&#39;: 136, &#39;amount_value&#39;: 77753.28},
#  {&#39;id&#39;: 137, &#39;amount_value&#39;: 98220.99},
#  {&#39;id&#39;: 138, &#39;amount_value&#39;: 80601.72},
#  {&#39;id&#39;: 139, &

# %%
data[]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-cyan-fg">  File </span><span class="ansi-green-fg">&#34;&lt;command-4372736443989381&gt;&#34;</span><span class="ansi-cyan-fg">, line </span><span class="ansi-green-fg">1</span>
# <span class="ansi-red-fg">    data[]</span>
#          ^
# <span class="ansi-red-fg">SyntaxError</span><span class="ansi-red-fg">:</span> invalid syntax
# </div>

# %%
invoice_array = df.InvoiceNo.unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
invoice_array
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: array([&#39;536365&#39;, &#39;536366&#39;, &#39;536367&#39;, ..., &#39;581585&#39;, &#39;581586&#39;, &#39;581587&#39;],
#       dtype=object)</div>

# %%
invoice_array[-1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: &#39;581587&#39;</div>

# %%
len(invoice_array)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 25900</div>

# %%
# each invoice should have a certain number of products

# generating a random number for each invoice -> number of products from that invoice
# randomly choose the product from the correlation dict * randomly generated number
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
int(cor[47]['StockCode'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: 20679</div>

# %%
df.groupby('InvoiceNo').describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="8" halign="left">Quantity</th>
#       <th colspan="8" halign="left">UnitPrice</th>
#       <th colspan="8" halign="left">CustomerID</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>InvoiceNo</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>536365</th>
#       <td>7.0</td>
#       <td>5.714286</td>
#       <td>1.799471</td>
#       <td>2.0</td>
#       <td>6.00</td>
#       <td>6.0</td>
#       <td>6.00</td>
#       <td>8.0</td>
#       <td>7.0</td>
#       <td>3.910000</td>
#       <td>1.737316</td>
#       <td>2.55</td>
#       <td>3.070</td>
#       <td>3.39</td>
#       <td>3.82</td>
#       <td>7.65</td>
#       <td>7.0</td>
#       <td>17850.0</td>
#       <td>0.0</td>
#       <td>17850.0</td>
#       <td>17850.0</td>
#       <td>17850.0</td>
#       <td>17850.0</td>
#       <td>17850.0</td>
#     </tr>
#     <tr>
#       <th>536366</th>
#       <td>2.0</td>
#       <td>6.000000</td>
#       <td>0.000000</td>
#       <td>6.0</td>
#       <td>6.00</td>
#       <td>6.0</td>
#       <td>6.00</td>
#       <td>6.0</td>
#       <td>2.0</td>
#       <td
td>
#       <td>15498.0</td>
#       <td>15498.0</td>
#       <td>15498.0</td>
#       <td>15498.0</td>
#       <td>15498.0</td>
#     </tr>
#     <tr>
#       <th>C581568</th>
#       <td>1.0</td>
#       <td>-5.000000</td>
#       <td>NaN</td>
#       <td>-5.0</td>
#       <td>-5.00</td>
#       <td>-5.0</td>
#       <td>-5.00</td>
#       <td>-5.0</td>
#       <td>1.0</td>
#       <td>10.950000</td>
#       <td>NaN</td>
#       <td>10.95</td>
#       <td>10.950</td>
#       <td>10.95</td>
#       <td>10.95</td>
#       <td>10.95</td>
#       <td>1.0</td>
#       <td>15311.0</td>
#       <td>NaN</td>
#       <td>15311.0</td>
#       <td>15311.0</td>
#       <td>15311.0</td>
#       <td>15311.0</td>
#       <td>15311.0</td>
#     </tr>
#     <tr>
#       <th>C581569</th>
#       <td>2.0</td>
#       <td>-3.000000</td>
#       <td>2.828427</td>
#       <td>-5.0</td>
#       <td>-4.00</td>
#       <td>-3.0</td>
#       <td>-2.00</td>
#       <td>-1.0</td>
#       <td>2.0</td>
#       <td>1.250000</td>
#       <td>0.000000</td>
#       <td>1.25</td>
#       <td>1.250</td>
#       <td>1.25</td>
#       <td>1.25</td>
#       <td>1.25</td>
#       <td>2.0</td>
#       <td>17315.0</td>
#       <td>0.0</td>
#       <td>17315.0</td>
#       <td>17315.0</td>
#       <td>17315.0</td>
#       <td>17315.0</td>
#       <td>17315.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 24 columns</p>
# </div>

# %%
df.groupby('InvoiceNo').mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Quantity</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#     </tr>
#     <tr>
#       <th>InvoiceNo</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>536365</th>
#       <td>5.714286</td>
#       <td>3.910000</td>
#       <td>17850.0</td>
#     </tr>
#     <tr>
#       <th>536366</th>
#       <td>6.000000</td>
#       <td>1.850000</td>
#       <td>17850.0</td>
#     </tr>
#     <tr>
#       <th>536367</th>
#       <td>6.916667</td>
#       <td>4.853333</td>
#       <td>13047.0</td>
#     </tr>
#     <tr>
#       <th>536368</th>
#       <td>3.750000</td>
#       <td>4.775000</td>
#       <td>13047.0</td>
#     </tr>
#     <tr>
#       <th>536369</th>
#       <td>3.000000</td>
#       <td>5.950000</td>
#       <td>13047.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>C581484</th>
#       <td>-80995.000000</td>
#       <td>2.080000</td>
#       <td>16446.0</td>
#     </tr>
#     <tr>
#       <th>C581490</th>
#       <td>-11.500000</td>
#       <td>1.390000</td>
#       <td>14397.0</td>
#     </tr>
#     <tr>
#       <th>C581499</th>
#       <td>-1.000000</td>
#       <td>224.690000</td>
#       <td>15498.0</td>
#     </tr>
#     <tr>
#       <th>C581568</th>
#       <td>-5.000000</td>
#       <td>10.950000</td>
#       <td>15311.0</td>
#     </tr>
#     <tr>
#       <th>C581569</th>
#       <td>-3.000000</td>
#       <td>1.250000</td>
#       <td>17315.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 3 columns</p>
# </div>

# %%
# TODO: check for returns in dataset

# %%
df['Quantity'].mean()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: 9.55224954743324</div>

# %%
no_items = random.randrange(0,15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
no_items
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[58]: 6</div>

# %%
def generate_invoice_object_quantity(number_of_invoices):
  #   number_of_invoices -> the number of invoices that we want to generate
  #   returns an array with number_of_invoices random elements
  #   the random number will be beetween 1 and 15
  invoice_no_elements = []
  for i in range(number_of_invoices):
    invoice_no_elements.append(random.randrange(1,15))
  
  return invoice_no_elements
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cor[1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: {&#39;StockCode&#39;: &#39;71053&#39;, &#39;Description&#39;: &#39;WHITE METAL LANTERN&#39;}</div>

# %%
cor[1]['Description']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: &#39;WHITE METAL LANTERN&#39;</div>

# %%
def choose_product(data):
  # choose a random product from the input array
  # returns a single element
  return random.choice(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chosen_product = choose_product(cor)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chosen_product
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: {&#39;StockCode&#39;: &#39;90214R&#39;, &#39;Description&#39;: &#39;LETTER &#34;R&#34; BLING KEY RING&#39;}</div>

# %%
# generate country
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df['Country'].unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[77]: array([&#39;United Kingdom&#39;, &#39;France&#39;, &#39;Australia&#39;, &#39;Netherlands&#39;, &#39;Germany&#39;,
#        &#39;Norway&#39;, &#39;EIRE&#39;, &#39;Switzerland&#39;, &#39;Spain&#39;, &#39;Poland&#39;, &#39;Portugal&#39;,
#        &#39;Italy&#39;, &#39;Belgium&#39;, &#39;Lithuania&#39;, &#39;Japan&#39;, &#39;Iceland&#39;,
#        &#39;Channel Islands&#39;, &#39;Denmark&#39;, &#39;Cyprus&#39;, &#39;Sweden&#39;, &#39;Austria&#39;,
#        &#39;Israel&#39;, &#39;Finland&#39;, &#39;Bahrain&#39;, &#39;Greece&#39;, &#39;Hong Kong&#39;, &#39;Singapore&#39;,
#        &#39;Lebanon&#39;, &#39;United Arab Emirates&#39;, &#39;Saudi Arabia&#39;,
#        &#39;Czech Republic&#39;, &#39;Canada&#39;, &#39;Unspecified&#39;, &#39;Brazil&#39;, &#39;USA&#39;,
#        &#39;European Community&#39;, &#39;Malta&#39;, &#39;RSA&#39;], dtype=object)</div>

# %%
def generate_country():
  # randomly choose a country from the list
  return random.choice(df['Country'].unique())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
generated_country = generate_country()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
generated_country
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[80]: &#39;Netherlands&#39;</div>

# %%
import time
from datetime import datetime, timedelta

def random_date(start, end):
    """
    This function will return a random datetime between two datetime 
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import time
from datetime import datetime, timedelta
from random import randrange

def random_date(start, end):
    """
    This function will return a random datetime between two datetime 
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)

def str_time_prop(start):

    stime = datetime.strptime(start, '%m/%d/%Y %H:%M')
    etime = datetime.strptime(start, '%m/%d/%Y %H:%M') + timedelta(hours=1)

    new_date = random_date(stime, etime)
    return new_date


def generate_random_date(start):
    return str_time_prop(start)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df['InvoiceDate'].iloc[-1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[111]: &#39;12/9/2011 12:50&#39;</div>

# %%
str(generate_random_date(df['InvoiceDate'].iloc[-1]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[108]: &#39;2011-12-09 13:01:50&#39;</div>

# %%
#
#
#
#
# solved datetime bug
#
#
#

# %%
type(df['InvoiceDate'].iloc[-1])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: str</div>

# %%
from datetime import datetime
start_time = datetime.strptime(df['InvoiceDate'].iloc[-1], '%m/%d/%Y %H:%M')
start_time
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[149]: datetime.datetime(2011, 12, 9, 12, 50)</div>

# %%
import datetime
date = datetime.datetime(int(start_time))
for i in range(5): 
    date += datetime.timedelta(days=1)
    print(date)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4372736443989977&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">import</span> datetime
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>date <span class="ansi-blue-fg">=</span> datetime<span class="ansi-blue-fg">.</span>datetime<span class="ansi-blue-fg">(</span>int<span class="ansi-blue-fg">(</span>start_time<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> <span class="ansi-green-fg">for</span> i <span class="ansi-green-fg">in</span> range<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">5</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>     date <span class="ansi-blue-fg">+=</span> datetime<span class="ansi-blue-fg">.</span>timedelta<span class="ansi-blue-fg">(</span>days<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>     print<span class="ansi-blue-fg">(</span>date<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">TypeError</span>: int() argument must be a string, a bytes-like object or a number, not &#39;datetime.datetime&#39;</div>

# %%
type(start_time)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[111]: datetime.datetime</div>

# %%
import datetime
plus_one_hour = datetime.datetime.strptime("21:00:00", "%H:%M:%S") + datetime.timedelta(hours=2)
print(plus_one_hour.strftime("%H:%M:%S"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">23:00:00
# </div>

# %%
# 
# 
# 
#

# %%
ml_set.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: (3000000, 2)</div>

# %%
ml_set
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>amount_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>60132.36</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>7068.37</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>58198.35</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>28525.11</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>37420.89</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2999995</th>
#       <td>2999995</td>
#       <td>73781.16</td>
#     </tr>
#     <tr>
#       <th>2999996</th>
#       <td>2999996</td>
#       <td>28945.24</td>
#     </tr>
#     <tr>
#       <th>2999997</th>
#       <td>2999997</td>
#       <td>87022.32</td>
#     </tr>
#     <tr>
#       <th>2999998</th>
#       <td>2999998</td>
#       <td>62171.90</td>
#     </tr>
#     <tr>
#       <th>2999999</th>
#       <td>2999999</td>
#       <td>59471.26</td>
#     </tr>
#   </tbody>
# </table>
# <p>3000000 rows × 2 columns</p>
# </div>

# %%
ml_set['amount_currency'] = 'USD'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>amount_value</th>
#       <th>amount_currency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>60132.36</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>7068.37</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>58198.35</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>28525.11</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>37420.89</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2999995</th>
#       <td>2999995</td>
#       <td>73781.16</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>2999996</th>
#       <td>2999996</td>
#       <td>28945.24</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>2999997</th>
#       <td>2999997</td>
#       <td>87022.32</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>2999998</th>
#       <td>2999998</td>
#       <td>62171.90</td>
#       <td>USD</td>
#     </tr>
#     <tr>
#       <th>2999999</th>
#       <td>2999999</td>
#       <td>59471.26</td>
#       <td>USD</td>
#     </tr>
#   </tbody>
# </table>
# <p>3000000 rows × 3 columns</p>
# </div>

# %%
def random_channel(row):
    channel = ''
    rnd =  random.randrange(101)
    if  0 < rnd <= 10:
        channel = 'pos'
    elif 10 < rnd <= 50:
        channel = 'online'
    elif 51 < rnd <= 100:
        channel = 'virtual'
    else:
        channel = 'mobile'
    
    return channel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['channel'] = ml_set.apply(random_channel, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set.channel.unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: array([&#39;online&#39;, &#39;virtual&#39;, &#39;pos&#39;, &#39;mobile&#39;], dtype=object)</div>

# %%
def deviceDetails_browser(row):
    browser = ''
    rnd =  random.randrange(101)
    if  0 < rnd <= 10:
        browser = 'mozilla'
    elif 10 < rnd <= 50:
        browser = 'chrome'
    elif 51 < rnd <= 100:
        browser = 'edge'
    else:
        browser = 'chromio'
    
    return browser
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['deviceDetails_browser'] = ml_set.apply(deviceDetails_browser, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def deviceDetails_device(row):
    device = ''
    rnd =  random.randrange(101)
    if  0 < rnd <= 10:
        device = 'mobile'
    elif 10 < rnd <= 50:
        device = 'pc'
    else:
        device = 'pos'
    
    return device
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['deviceDetails_device'] = ml_set.apply(deviceDetails_device, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import socket
import struct
def deviceDetails_deviceIp(row):
    ip = socket.inet_ntoa(struct.pack('>I', random.randint(1, 0xffffffff)))
    return ip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['deviceDetails_deviceIp'] = ml_set.apply(deviceDetails_deviceIp, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import string
def merchantRefTransactionId(row):
    letters = string.digits
    return ''.join(random.choice(letters) for i in range(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['merchantRefTransactionId'] = ml_set.apply(merchantRefTransactionId, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def paymentMethod_apmType(row):
    amp = ''
    rnd =  random.randrange(101)
    if  0 < rnd <= 10:
        amp = 'chip'
    elif 10 < rnd <= 50:
        amp = 'magstripe '
    else:
        amp = 'nfcc'
    
    return amp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_apmType'] = ml_set.apply(paymentMethod_apmType, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import string
def paymentMethod_cardNumber(row):
    card_number = ''
    numbers = string.digits
    for part in range(4):
        card_number += ''.join((random.choice(numbers) for i in range(4))) + '-'
    return card_number[:-1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_cardNumber'] = ml_set.apply(paymentMethod_cardNumber, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def paymentMethod_cardType(row):
    card_type = ''
    rnd =  random.randrange(201)
    if  0 < rnd <= 10:
        card_type = 'MasterCard'
    elif 10 < rnd <= 50:
        card_type = 'Visa '
    elif 51 < rnd <= 100:
        card_type = 'Discover '
    elif 51 < rnd <= 100:
        card_type = 'JCB'
    else:
        card_type = 'American Express'
    
    return card_type
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_cardType'] = ml_set.apply(paymentMethod_cardType, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def paymentMethod_cardSubType(row):
    card_subtype = ''
    rnd =  random.randrange(201)
    if  0 < rnd <= 10:
        card_subtype = 'Secured'
    elif 10 < rnd <= 50:
        card_subtype = 'Prepaid '
    elif 51 < rnd <= 100:
        card_subtype = 'Business '
    elif 51 < rnd <= 100:
        card_subtype = 'Student'
    else:
        card_subtype = 'Generic'
    
    return card_subtype
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_cardSubType'] = ml_set.apply(paymentMethod_cardSubType, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import string
def paymentMethod_cvv(row):
    numbers = string.digits
    return ''.join((random.choice(numbers) for i in range(3)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_cvv'] = ml_set.apply(paymentMethod_cvv, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def paymentMethod_encodedPaymentToken(row):
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(8))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_encodedPaymentToken'] = ml_set.apply(paymentMethod_encodedPaymentToken, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>amount_value</th>
#       <th>amount_currency</th>
#       <th>channel</th>
#       <th>deviceDetails_browser</th>
#       <th>deviceDetails_device</th>
#       <th>deviceDetails_deviceIp</th>
#       <th>merchantRefTransactionId</th>
#       <th>paymentMethod_apmType</th>
#       <th>paymentMethod_cardNumber</th>
#       <th>paymentMethod_cardType</th>
#       <th>paymentMethod_cardSubType</th>
#       <th>paymentMethod_cvv</th>
#       <th>paymentMethod_encodedPaymentToken</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>52674.11</td>
#       <td>USD</td>
#       <td>online</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>49.163.133.162</td>
#       <td>8068408692</td>
#       <td>magstripe</td>
#       <td>2385-5404-2091-8967</td>
#       <td>Discover</td>
#       <td>Generic</td>
#       <td>947</td>
#       <td>djKIQXjZ</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>85296.01</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>chrome</td>
#       <td>pos</td>
#       <td>160.65.195.137</td>
#       <td>4377079229</td>
#       <td>magstripe</td>
#       <td>9116-8339-7115-5513</td>
#       <td>American Express</td>
#       <td>Prepaid</td>
#       <td>942</td>
#       <td>UnGsLyHj</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>90216.63</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>chrome</td>
#       <td>pc</td>
#       <td>161.195.45.60</td>
#       <td>9656269727</td>
#       <td>magstripe</td>
#       <td>3602-3265-6476-3263</td>
#       <td>Discover</td>
#       <td>Secured</td>
#       <td>838</td>
#       <td>iDljPjZZ</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>71377.42</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>204.88.205.7</td>
#       <td>1612067815</td>
#       <td>magstripe</td>
#       <td>9300-0028-9239-8479</td>
#       <td>American Express</td>
#       <td>Generic</td>
#       <td>071</td>
#       <td>xqbytldy</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>45932.43</td>
#       <td>USD</td>
#       <td>pos</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>226.121.147.17</td>
#       <td>0421966816</td>
#       <td>nfcc</td>
#       <td>7572-4620-6384-7848</td>
#       <td>American Express</td>
#       <td>Generic</td>
#       <td>735</td>
#       <td>RHKDHTUd</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from random import randrange

def paymentMethod_expiryMonth(row):
    return randrange(12)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_expiryMonth'] = ml_set.apply(paymentMethod_expiryMonth, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from random import randrange

def paymentMethod_expiryYear(row):
    start_year = randrange(2018,2020)
    return randrange(start_year, start_year + 10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set['paymentMethod_expiryYear'] = ml_set.apply(paymentMethod_expiryYear, axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ml_set.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>amount_value</th>
#       <th>amount_currency</th>
#       <th>channel</th>
#       <th>deviceDetails_browser</th>
#       <th>deviceDetails_device</th>
#       <th>deviceDetails_deviceIp</th>
#       <th>merchantRefTransactionId</th>
#       <th>paymentMethod_apmType</th>
#       <th>paymentMethod_cardNumber</th>
#       <th>paymentMethod_cardType</th>
#       <th>paymentMethod_cardSubType</th>
#       <th>paymentMethod_cvv</th>
#       <th>paymentMethod_encodedPaymentToken</th>
#       <th>paymentMethod_expiryMonth</th>
#       <th>paymentMethod_expiryYear</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>52674.11</td>
#       <td>USD</td>
#       <td>online</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>49.163.133.162</td>
#       <td>8068408692</td>
#       <td>magstripe</td>
#       <td>2385-5404-2091-8967</td>
#       <td>Discover</td>
#       <td>Generic</td>
#       <td>947</td>
#       <td>djKIQXjZ</td>
#       <td>8</td>
#       <td>2028</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>85296.01</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>chrome</td>
#       <td>pos</td>
#       <td>160.65.195.137</td>
#       <td>4377079229</td>
#       <td>magstripe</td>
#       <td>9116-8339-7115-5513</td>
#       <td>American Express</td>
#       <td>Prepaid</td>
#       <td>942</td>
#       <td>UnGsLyHj</td>
#       <td>1</td>
#       <td>2020</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>90216.63</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>chrome</td>
#       <td>pc</td>
#       <td>161.195.45.60</td>
#       <td>9656269727</td>
#       <td>magstripe</td>
#       <td>3602-3265-6476-3263</td>
#       <td>Discover</td>
#       <td>Secured</td>
#       <td>838</td>
#       <td>iDljPjZZ</td>
#       <td>0</td>
#       <td>2024</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>71377.42</td>
#       <td>USD</td>
#       <td>virtual</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>204.88.205.7</td>
#       <td>1612067815</td>
#       <td>magstripe</td>
#       <td>9300-0028-9239-8479</td>
#       <td>American Express</td>
#       <td>Generic</td>
#       <td>071</td>
#       <td>xqbytldy</td>
#       <td>7</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>45932.43</td>
#       <td>USD</td>
#       <td>pos</td>
#       <td>edge</td>
#       <td>pos</td>
#       <td>226.121.147.17</td>
#       <td>0421966816</td>
#       <td>nfcc</td>
#       <td>7572-4620-6384-7848</td>
#       <td>American Express</td>
#       <td>Generic</td>
#       <td>735</td>
#       <td>RHKDHTUd</td>
#       <td>6</td>
#       <td>2026</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ml_set.to_csv('ml_datasert.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
